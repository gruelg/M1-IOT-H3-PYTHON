# %% [markdown]
# # Implémenter une régression linéaire

# %%
import pandas as pd

# %%
priceAvaibility = pd.read_csv('price_availability.csv', delimiter=';')

# %%
priceAvaibility.head()
# Out:
#    listing_id         day                       created  available  \
# 0     9810829  2018-12-08  2018-09-27 06:14:10.000+0000       True
# 1     9810829  2018-12-08  2018-09-26 19:34:02.000+0000       True
# 2    20897010  2018-12-09  2018-09-27 10:38:57.000+0000       True
# 3    20897010  2018-12-09  2018-09-27 06:10:27.000+0000       True
# 4    20897010  2018-12-09  2018-09-26 19:30:25.000+0000       True
#
#   local_currency  local_price  min_nights
# 0            EUR          160           1
# 1            EUR          160           1
# 2            EUR          172           2
# 3            EUR          172           2
# 4            EUR          172           2

# %%
priceAvaibility['listing_id'].value_counts()

# %% [markdown]
# ### tous les individues ont un prix

# %%
listingsFinal = pd.read_csv("listings_final.csv", delimiter=";",index_col = 0)

# %%
listingsFinal.head(10)
# Out:
#    listing_id                                               name  \
# 0    28581061                                    La maison Clery
# 1      661961                studio PARIS PLACE EDITH PIAF 75020
# 2     1261705           chambre privée à louer @ paris oberkampf
# 3     1318834                     Appartement au coeur du Marais
# 4     1677091                                Lovely & Quiet flat
# 5     2157481                CENTRAL ET BIEN CONÇU,50m2+terrasse
# 6     1140610                      Petit atelier canal st Martin
# 7     5662637  Sophisticated & Sunny Opulent 1BR *Opéra *4 Gu...
# 8     5981388              Paris 16 - Elysées-Kléber-Trocadero /
# 9      149534                 GREAT WARM FULL APT LE HAUT MARAIS
#
#            type   city                  neighborhood   latitude  longitude  \
# 0  private_room  Paris             2e arrondissement  48.869292   2.348335
# 1   entire_home  Paris                           NaN  48.867284   2.403255
# ...

# %% [markdown]
# # Données d'entrée

# %%
resultMeans = priceAvaibility.groupby('listing_id').mean()
resultMeans.describe()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_func_and_vals(self, kind, how, values, is_numeric)
#     420         try:
# --> 421             func = self._get_cython_function(kind, how, values, is_numeric)
#     422         except NotImplementedError:
#
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_function(self, kind, how, values, is_numeric)
#     394         if func is None:
# --> 395             raise NotImplementedError(
#     396                 f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->int64]
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
priceAvaibility.dtypes
# Out:
# available      float64
# local_price    float64
# min_nights     float64
# dtype: object

# %%
result = pd.merge(listingsFinal, priceAvaibility['available','local_price'],on='listing_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('available', 'local_price')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
priceAvaibility.dtypes
# Out:
# listing_id         int64
# day               object
# created           object
# available           bool
# local_currency    object
# local_price        int64
# min_nights         int64
# dtype: object
