# %% [markdown]
# # Implémenter une régression linéaire

# %%
import pandas as pd 
import numpy as np

# %%
priceAvaibility = pd.read_csv('price_availability.csv', delimiter=';')

# %%
priceAvaibility.head()
# Out:
#    listing_id         day                       created  available  \
# 0     9810829  2018-12-08  2018-09-27 06:14:10.000+0000       True
# 1     9810829  2018-12-08  2018-09-26 19:34:02.000+0000       True
# 2    20897010  2018-12-09  2018-09-27 10:38:57.000+0000       True
# 3    20897010  2018-12-09  2018-09-27 06:10:27.000+0000       True
# 4    20897010  2018-12-09  2018-09-26 19:30:25.000+0000       True
#
#   local_currency  local_price  min_nights
# 0            EUR          160           1
# 1            EUR          160           1
# 2            EUR          172           2
# 3            EUR          172           2
# 4            EUR          172           2

# %%
priceAvaibility['listing_id'].value_counts()
# Out:
# 24054752    529
# 1132615     528
# 28422066    528
# 4206844     528
# 18305959    528
#            ...
# 15751342    121
# 6657528     121
# 28838519    120
# 22953092    120
# 9765141     119
# Name: listing_id, Length: 11749, dtype: int64

# %% [markdown]
# ### tous les individues ont un prix

# %%
listingsFinal = pd.read_csv("listings_final.csv", delimiter=";",index_col = 0)

# %%
listingsFinal
# Out:
#      listing_id                                      name          type  \
# 0      28581061                           La maison Clery  private_room
# 1        661961       studio PARIS PLACE EDITH PIAF 75020   entire_home
# 2       1261705  chambre privée à louer @ paris oberkampf  private_room
# 3       1318834            Appartement au coeur du Marais   entire_home
# 4       1677091                       Lovely & Quiet flat   entire_home
# ..          ...                                       ...           ...
# 995    28335197          Studio cosy Jardin du Luxembourg   entire_home
# 996    28583013    Charmant  30m2 - Faubourg Saint Martin   entire_home
# 997    28628316       Cosy flat in the marais - Best area   entire_home
# 998    28792796         Appartement 3 chambres madeleine.   entire_home
# 999    28682896                          Village Jourdain  private_room
#
#       city                    neighborhood   latitude  longitude  \
# 0    Paris               2e arrondissement  48.869292   2.348335
# 1    Paris                             NaN  48.867284   2.403255
# 2    Paris                             NaN  48.867894   2.375897
# 3    Paris                      République  48.870370   2.358510
# 4    Paris    Buttes-Chaumont - Belleville  48.874149   2.373700
# ..     ...                             ...        ...        ...
# 995  Paris  Saint Germain des Prés - Odéon  48.848695   2.325857
# 996  Paris                      République  48.871623   2.358006
# 997  Paris               2e arrondissement  48.867434   2.351771
# 998  Paris             Madeleine - Vendôme  48.870109   2.321475
# 999  Paris    Buttes-Chaumont - Belleville  48.875425   2.395240
#
#      person_capacity  beds  bedrooms  bathrooms  is_rebookable  \
# 0                  1     1         1        2.0          False
# 1                  2     1         1        1.0          False
# 2                  1     1         1        1.0          False
# 3                  3     2         2        1.0          False
# 4                  2     1         1        1.0          False
# ..               ...   ...       ...        ...            ...
# 995                2     1         0        1.0          False
# 996                3     1         1        1.0          False
# 997                4     2         1        1.0          False
# 998                6     4         2        1.5          False
# 999                2     1         1        1.0          False
#
#      is_new_listing  is_fully_refundable  is_host_highly_rated  \
# 0              True                 True                 False
# 1             False                 True                  True
# 2             False                 True                  True
# 3             False                 True                 False
# 4             False                 True                  True
# ..              ...                  ...                   ...
# 995            True                 True                 False
# 996            True                 True                 False
# 997            True                 True                  True
# 998            True                 True                 False
# 999            True                 True                 False
#
#      is_business_travel_ready  pricing_weekly_factor  pricing_monthly_factor
# 0                       False                   1.00                    1.00
# 1                       False                   0.88                    0.69
# 2                       False                   1.00                    1.00
# 3                       False                   0.82                    0.48
# 4                       False                   0.95                    0.90
# ..                        ...                    ...                     ...
# 995                     False                   0.79                    1.00
# 996                     False                   1.00                    1.00
# 997                     False                   1.00                    1.00
# 998                     False                   1.00                    1.00
# 999                     False                   1.00                    1.00
#
# [1000 rows x 18 columns]

# %% [markdown]
# # Données d'entrée

# %%
resultMeans = priceAvaibility.groupby('listing_id').mean()

# %%
resultMeans.tail(10)
# Out:
#             available  local_price  min_nights
# listing_id
# 28832238     0.823834   173.450777    2.000000
# 28833455     0.397436   275.000000    2.000000
# 28834404     0.817460    94.388889    2.000000
# 28834563     0.462338    55.420779    1.000000
# 28835343     0.112782    30.000000    1.000000
# 28836096     0.082707   321.428571    1.022556
# 28838519     0.083333    54.483333    5.000000
# 28840013     0.743083   112.122530    2.000000
# 28846494     0.225564   168.037594    4.000000
# 28851976     0.812030   128.000000    2.000000

# %%
resultMeans['listing_id'] = priceAvaibility['listing_id'].unique()

# %%
listingsFinal.drop(589, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-168-6e103639c736> in <module>
# ----> 1 listingsFinal.drop(589, inplace=True)
#
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4160                 weight  1.0     0.8
#    4161         """
# -> 4162         return super().drop(
#    4163             labels=labels,
#    4164             axis=axis,
#
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3882         for axis, labels in axes.items():
#    3883             if labels is not None:
# -> 3884                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3885
#    3886         if inplace:
#
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3916                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3917             else:
# -> 3918                 new_axis = axis.drop(labels, errors=errors)
#    3919             result = self.reindex(**{axis_name: new_axis})
#    3920
#
# c:\users\gruel\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5276         if mask.any():
#    5277             if errors != "ignore":
# -> 5278                 raise KeyError(f"{labels[mask]} not found in axis")
#    5279             indexer = indexer[~mask]
#    5280         return self.delete(indexer)
#
# KeyError: '[589] not found in axis'

# %%
test = listingsFinal['listing_id'].isin(resultMeans['listing_id'])

# %%
test.value_counts()
# Out:
# True    999
# Name: listing_id, dtype: int64

# %%
listingsFinal['listing_id']
# Out:
# 0      28581061
# 1        661961
# 2       1261705
# 3       1318834
# 4       1677091
#          ...
# 995    28335197
# 996    28583013
# 997    28628316
# 998    28792796
# 999    28682896
# Name: listing_id, Length: 999, dtype: int64

# %%
for i in range(1,1000):
    if test[i]== False:
        print(i)
# Out:
# 589

# %%
listingsFinal['listing_id']= (listingsFinal['listing_id'].isin(resultMeans['listing_id']) == True)

# %%
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: listing_id, Length: 999, dtype: bool

# %%
result = pd.merge(listingsFinal, resultMeans[['available','local_price','min_nights']],on='listing_id')
